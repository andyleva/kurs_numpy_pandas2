# %% [markdown]
# ## Домашнее задание к уроку
# #### Урок 4. Оценка и интерпретация полученной модели. Обсуждение курсового проекта.

# %% [markdown]
# 1.Расскажите, как работает регуляризация в решающих деревьях, какие параметры мы штрафуем в данных алгоритмах?

# %% [markdown]
# В существующих алгоритмах обучения построение решающего дерева заканчивается по достижении нулевого уровня ошибки на обучающей выборке. Метод регуляризации заключается в "штрафовании" модели за слишком большие веса путем добавления нового члена к ошибке, лямда, называемый квадратичным регуляризатором. Чем больше его  𝜆 , тем меньшая сложность модели будет получаться в процессе такого обучения. Смысл регуляризации заключается в минимизации функционала ошибки с ограничением весов.
# Различают L1-регуляризация (lasso, регуляризация через манхэттенское расстояние - прибавление к лосс-функции суммы весов в модуле) и L2-регуляризация (ridge, регуляризация Тихонова - прибавление суммы весов в квадрате с множителем лямбда)
# Штрафуются очень малые и большие весовые значения для модели.

# %% [markdown]
# 2.По какому принципу рассчитывается "важность признака (feature_importance)" в ансамблях деревьев?

# %% [markdown]
# Важность признака (feature importance) - это среднее усиление по всем узлам, в которых используется признак. сколько раз признак встретился в деревьях. Важность признака, демонстрируемая важностью Джини (уменьшение ошибки с использованием этого признака):
